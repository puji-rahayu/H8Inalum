# %% [markdown]
# # Hipotesis Testing

# %%
import statsmodels.api as sm
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
import random
import scipy.stats as stats
import seaborn as sns

# %matplotlib inline

# %%
sns.set(rc = {'figure.figsize':(13, 7.5)})

# %%
np.random.seed(42)

normal_distribution_male_mass_pound = np.random.normal(loc=181, scale=24, size=6000)

# %%
normal_distribution_feale_mass_pound = np.random.normal(loc=132, scale=24, size=6500)

# %%
all_mass_value = np.concatenate((normal_distribution_male_mass_pound, normal_distribution_feale_mass_pound), axis=0)

# %%
df_ppl_mass = pd.DataFrame(data={'mass_pounds':all_mass_value})

# %%
df_ppl_mass.head()
# Out:
#    mass_pounds
# 0   192.921140
# 1   177.681657
# 2   196.544525
# 3   217.552717
# 4   175.380319

# %%
sns.distplot(df_ppl_mass['mass_pounds'], color='darkslategrey')
plt.xlabel('mass [pounds]')
plt.ylabel('probability of occurance')
plt.title('Hipotesis Testing')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-38-6c9eed143646> in <module>
#       1 sns.distplot(df_ppl_mass['mass_pounds'], color='darkslategrey')
# ----> 2 plt.xlabel('mass [pounds]')
#       3 plt.ylabel('probability of occurance')
#       4 plt.title('Hipotesis Testing')
#       5 plt.show()
#
# TypeError: 'str' object is not callable

# %%
print('Calculate Population Mean')

pop_mean_mass = df_ppl_mass['mass_pounds'].mean()
pop_mean_mass

# %%
print('Calculate Population Standart Deviation')

pop_std_dev_mass = df_ppl_mass['mass_pounds'].std()
pop_std_dev_mass

# %%
print('Sample 25 orang, 300 kali sampling')

sample_means = []
n = 25

for sample in range(0, 300):
    #random values
    sample_values = np.random.choice(a=df_ppl_mass['mass_pounds'], size=n)
    sample_mean = np.mean(sample_values)
    sample_means.append(sample_mean)
# Out:
# Sample 25 orang, 300 kali sampling

# %%
sample_means
# Out:
# [152.57384109015214,
#  163.72207129987416,
#  152.09934660338203,
#  163.5220270795167,
#  165.80193865727776,
#  159.26748778839624,
#  147.23902164776143,
#  161.52797105677445,
#  153.1713625435935,
#  172.16957824669547,
#  148.22785325869594,
#  158.87051799985417,
#  161.74928755167588,
#  155.78508606367348,
#  157.08804177789554,
#  148.76470320918835,
#  152.22300662311022,
#  155.19672252177403,
#  151.81855839277705,
#  165.68419552738018,
#  155.26693636984385,
#  147.8493365052109,
#  150.67454047698385,
#  161.837560005383,
#  152.51355569762814,
#  153.1857293693521,
#  168.64443797967888,
#  149.5508582151484,
#  147.9814613618473,
#  152.21710938656054,
#  151.4169962407979,
#  157.73669434986905,
#  152.03409081988735,
#  158.37016143662512,
#  146.72483066639467,
#  157.3368436743143,
#  156.1274936597146,
#  152.6210242246142,
#  169.2562798613477,
#  155.354705540798,
#  152.96430317517687,
#  142.87152633148347,
#  163.36023180700278,
#  154.95761841808655,
#  169.04449363207706,
#  155.73285410288517,
#  153.86328685874395,
#  149.5140732772208,
#  158.95487359828493,
#  155.9914845839952,
#  147.93256816449818,
#  147.36629008805184,
#  162.8103392397997,
#  158.1486643572621,
#  166.5530042640249,
#  144.75738456236377,
#  155.15759420169334,
#  146.85863162608229,
#  169.57893498975716,
#  165.33815256055715,
#  159.09109684106997,
#  163.56334750328912,
#  160.64603712298455,
#  160.54851363832861,
#  155.81959048493073,
#  154.98958804152036,
#  154.7163393277209,
#  149.36983171758897,
#  153.50241859765777,
#  159.24098135799656,
#  146.90418765838257,
#  162.6329170087942,
#  154.9577879730062,
#  160.64468137981828,
#  147.1288492729944,
#  151.63022973582173,
#  154.69656264022913,
#  155.72200072010205,
#  150.6104807623033,
#  163.94519616945297,
#  156.69388583031466,
#  155.75723781551724,
#  161.33425303262962,
#  163.90811771244603,
#  155.74273743373004,
#  164.11420411886564,
#  153.16998369008087,
#  150.7779443123262,
#  161.99605028915653,
#  159.07041552433338,
#  155.30047708993004,
#  155.3246272368414,
#  152.93604604987343,
#  161.9712083574686,
#  155.0126198254072,
#  145.57288491923498,
#  150.66482266736395,
#  149.3382283325272,
#  172.93680314109662,
#  162.31644024593598,
#  156.45728705553475,
#  143.08135693343849,
#  150.76296896605766,
#  146.52906430288212,
#  147.96912725586287,
#  147.52293724030488,
#  163.13696038901298,
#  149.9559151398514,
#  150.48642943736823,
#  166.64088946698269,
#  153.40100466086204,
#  163.64577335502244,
#  150.73910045711713,
#  143.2029403374047,
#  152.68404130911622,
#  159.60786197138495,
#  147.74874221680872,
#  157.72820397751383,
#  165.4361930229956,
#  156.89940161451804,
#  159.90503144984265,
#  158.39121856664943,
#  147.76781776713725,
#  168.60129524104303,
#  160.80382972898693,
#  149.64370693670614,
#  144.11456901109665,
#  152.60392486546095,
#  145.71000939286014,
#  161.60304527290873,
#  156.99390260709444,
#  152.20302401450218,
#  150.84102801211964,
#  149.8484753182166,
#  160.53274173587275,
#  164.9476981971623,
#  148.75109754973684,
#  157.61893644952036,
#  153.22319145757362,
#  152.9182445422255,
#  166.14629070501488,
#  174.50752563919596,
#  155.4518168859691,
#  157.064911611162,
#  143.5480917065678,
#  147.7616208073698,
#  161.181788030673,
#  165.2213464702788,
#  158.59615738122176,
#  163.4564879492385,
#  147.59729431634736,
#  158.02154195872285,
#  169.52452643638034,
#  170.2540172010067,
#  155.56572310971112,
#  158.40294785040362,
#  154.65554621895248,
#  157.95347044570852,
#  159.20447467535865,
#  155.16095966523787,
#  157.7978110575592,
#  148.46587892187617,
#  157.11914887858381,
#  162.08738531407363,
#  164.39527735194136,
#  159.2487840142209]

# %%
sns.distplot(sample_means)
plt.title('Distribution of sample means ($n=25$) of People..')
plt.xlabel('Sample man mass [pounds]')
plt.ylabel('Frequency of occurence')

plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-41-b2105f35ab3e> in <module>
#       1 sns.distplot(sample_means)
# ----> 2 plt.title('Distribution of sample means ($n=25$) of People..')
#       3 plt.xlabel('Sample man mass [pounds]')
#       4 plt.ylabel('Frequency of occurence')
#       5
#
# TypeError: 'str' object is not callable

# %%
# Calculate Sample Means

mean_of_sample_means = np.mean(sample_means)
mean_of_sample_means

# %%
# Calculate Std dev of sample means

std_dev_of_sample_means = np.std(sample_means)
std_dev_of_sample_means

# %%
# Calculate Std Error

standart_error = pop_std_dev_mass/np.sqrt(n)
standart_error

# %%
gye_sample_mean = 163

# %%
# Visualize gye sample means to sampling distribution

sns.distplot(sample_means)
plt.axvline(x = gye_sample_mean, linestyle='--', label='sample mean of ppl at gye')
plt.title = ('Distribution of Sample Mean')
plt.xlabel = ('trial')
plt.ylabel = ('trial')

plt.show()

# %%
lower_CI = mean_of_sample_means - 1.96*standart_error

# %%
upper_CI = mean_of_sample_means + 1.96*standart_error

# %%
print(lower_CI)
print(upper_CI)
print(pop_mean_mass)
# Out:
# 141.6910152125016
# 168.57810285095263
# 155.41775679950234

# %%
kde = stats.gaussian_kde(sample_means)
pos = np.linspace(np.min(sample_means), np.max(sample_means), 10000)
plt.plot(pos, kde(pos), color='teal')
shade = np.linspace(lower_CI, upper_CI, 300)
plt.fill_between(shade, kde(shade), alpha=0.45, color='teal')

# %%
# Probability DIsribution

# %%
#uniform

# %%
from scipy.stats import uniform

# %%
n = 10000
start = 10
width = 20
data_uniform = uniform.rvs(size=n, loc=start, scale=width)

# %%
sns.distplot(data_uniform)
plt.title('Uniform Dsitribution')
plt.ylabel('frequency')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-52-44f942d30faa> in <module>
#       1 sns.distplot(data_uniform)
# ----> 2 plt.title('Uniform Dsitribution')
#       3 plt.ylabel('frequency')
#       4 plt.show()
#
# TypeError: 'str' object is not callable

# %%
from scipy.stats import bernoulli
data_bern = bernoulli.rvs(size=10000, p=0.6)

# %%
sns.distplot(data_bern)

# %%
from scipy.stats import binom
data_binom = binom.rvs(n=10, p=0.4, size=10000)

# %%
sns.distplot(data_binom)

# %%
from scipy.stats import poisson
data_poisson = poisson.rvs(mu=3, size=10000)

# %%
sns.distplot(data_poisson)

# %%
from scipy.stats import norm
data_normal = norm.rvs(size=10000, loc=9, scale=1)

# %%
sns.distplot(data_normal)

# %%
from scipy.stats import expon
data_expon = expon.rvs(scale=1, loc=0, size=10000)

# %%
sns.distplot(data_expon)
plt.title('Exponetial Distribution')
ply.ylabel('frequency')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-60-c6318e77fd50> in <module>
#       1 sns.distplot(data_expon)
# ----> 2 plt.title('Exponetial Distribution')
#       3 ply.ylabel('frequency')
#       4 plt.show()
#
# TypeError: 'str' object is not callable

# %%
# Hyppothesis Testing

# %%
url = "https://raw.githubusercontent.com/kshedden/statswpy/master/NHANES/merged/nhanes_2015_2016.csv"
da = pd.read_csv(url)
da.head()
# Out:
#     SEQN  ALQ101  ALQ110  ALQ130  SMQ020  RIAGENDR  RIDAGEYR  RIDRETH1  \
# 0  83732     1.0     NaN     1.0       1         1        62         3
# 1  83733     1.0     NaN     6.0       1         1        53         3
# 2  83734     1.0     NaN     NaN       1         1        78         3
# 3  83735     2.0     1.0     1.0       2         2        56         3
# 4  83736     2.0     1.0     1.0       2         2        42         4
#
#    DMDCITZN  DMDEDUC2  ...  BPXSY2  BPXDI2  BMXWT  BMXHT  BMXBMI  BMXLEG  \
# 0       1.0       5.0  ...   124.0    64.0   94.8  184.5    27.8    43.3
# 1       2.0       3.0  ...   140.0    88.0   90.4  171.4    30.8    38.0
# 2       1.0       3.0  ...   132.0    44.0   83.4  170.1    28.8    35.6
# 3       1.0       5.0  ...   134.0    68.0  109.8  160.9    42.4    38.5
# 4       1.0       4.0  ...   114.0    54.0   55.2  164.9    20.3    37.4
#
#    BMXARML  BMXARMC  BMXWAIST  HIQ210
# 0     43.6     35.9     101.1     2.0
# 1     40.0     33.2     107.9     NaN
# 2     37.0     31.0     116.5     2.0
# 3     37.7     38.3     110.1     2.0
# 4     36.0     27.2      80.4     2.0
#
# [5 rows x 28 columns]

# %%
import statsmodels.api as sm

# %%
females = da[
    da['RIAGENDR'] == 2    
]

males = da[
    da['RIAGENDR'] == 1    
]

# %%
n1 = len(females)
mu1 = females["BMXBMI"].mean()
sd1 = females["BMXBMI"].std()

(n1, mu1, sd1)
# Out:
# (2976, 29.939945652173996, 7.75331880954568)

# %%
n2 = len(males)
mu2 = males["BMXBMI"].mean()
sd2 = males["BMXBMI"].std()

(n2, mu2, sd2)
# Out:
# (2759, 28.778072111846985, 6.252567616801485)

# %%
sm.stats.ztest(females['BMXBMI'].dropna(), males['BMXBMI'].dropna(), alternative='two-sided')
# Out:
# (6.1755933531383205, 6.591544431126401e-10)

# %%
plt.hist(females['BMXBMI'].dropna(), color='pink', bins=25)
plt.show()

# %%
plt.hist(males['BMXBMI'].dropna(), color='blue', bins=25)
plt.show()
